# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
#    **Raj Pondicherry, Data Scientist**

# %% [markdown]
# _I am interested in data science because I would like to upskill myself_

# %% [markdown]
# ### The code in cell 5 is a simple addition example in my first python notebook ###

# %%
1+1
# Out:
# 2

# %% [markdown]
# 1. Hyperlink Example
#
# [GOOGLE](www.google.com)
#
# 2. Buletted List of items Example
# * By Road
# * By Air
# * By Ship

# %%
# Horizontal Line EXAMPLE

import matplotlib.pyplot as plotLine
plotLine.hlines(3, 5, 10, color='blue')
plotLine.show()
